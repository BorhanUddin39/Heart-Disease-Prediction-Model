# %%
import pandas as pd

df = pd.read_csv("../data/encoded_data.csv")
df.head()
# Out:
#     Age     Sex       Chest Pain  Rest BP  Cholesterol Fasting Sugar  \
# 0  28.0    male  atypical angina    130.0   132.000000         False
# 1  29.0    male  atypical angina    120.0   243.000000         False
# 2  29.0    male  atypical angina    140.0   230.753086         False
# 3  30.0  female   typical angina    170.0   237.000000         False
# 4  31.0  female  atypical angina    100.0   219.000000         False
#
#                        Rest ECG  Max HR Ex Angina  ST Depression   ST Slope  \
# 0  left ventricular hypertrophy   185.0        no            0.0  upsloping
# 1                        normal   160.0        no            0.0  upsloping
# 2                        normal   170.0        no            0.0  upsloping
# 3         ST-T wave abnormality   170.0        no            0.0  upsloping
# 4         ST-T wave abnormality   150.0        no            0.0  upsloping
#
#   Fluoroscopy   Thalassemia             Heart Disease
# ...
